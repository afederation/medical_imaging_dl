# %% [markdown]
# ## Background
#
# Jeremy often brags (in a good way, like a proud dad) about how students in the course can get near-state-of-the-art models built using the fast.ai library with very little friction upfront. I wanted to put this idea to the test and decided to apply approaches *from the first lecture only* to a highly-cited cell paper from last year.
#
# As a biologist, a Cell paper can be the highlight of one's career. Cell publishes the best work from accross all fields of biology, and the [Kermany *et. al.*](http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5) paper from last year represented a breakthrough in applying deep learning to ocular pathology. Briefly, they used an imaging technology called retinal optical coherence tomography (OCT) to image healthy and disased eyes (3 possible conditions) and employed a panel of expert pathologists to classify them. They had multiple pathologist classify a subest of photos so they could get a measure of how accurate the humans were as well.
#
# ![oct image]()
#
# Let's give it a try.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *

# %% [markdown]
# ## Load the data
#
# Luckily, the data are already organized and released on the kaggle platform. They have a nice, pip-able API for accessing their data. You need an API token, and all the deatils are explaiend well in the [docs](https://github.com/Kaggle/kaggle-api).

# %%
# Download data from kaggle

#! pip install kaggle

# %%
# ! kaggle datasets download -d paultimothymooney/kermany2018

# %%
! ls data
! pwd
path = '/home/jupyter/kermany/data/'
# Out:
# kermany2018.zip  models  test  train  valid
# /home/jupyter/kermany

# %% [markdown]
# ## Pre-process the data
#
# The data come ordanized in three folders

# %%
src = (ImageList.from_folder(path)
       .split_by_folder(train='train', valid='test')
       .label_from_folder())
src
# Out:
# LabelLists;
#
# Train: LabelList (83484 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# DME,DME,DME,DME,DME
# Path: /home/jupyter/kermany/data;
#
# Valid: LabelList (968 items)
# x: ImageList
# Image (3, 496, 512),Image (3, 496, 768),Image (3, 496, 512),Image (3, 496, 768),Image (3, 496, 512)
# y: CategoryList
# DME,DME,DME,DME,DME
# Path: /home/jupyter/kermany/data;
#
# Test: None

# %%
tfms = get_transforms()

# %%
data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))

# %%
data.show_batch(rows=3, figsize=(12,9))

# %%
data.classes
# Out:
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %%
learn = cnn_learner(data, models.resnet34, metrics=[accuracy, error_rate])

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.427891</td>
#       <td>0.228002</td>
#       <td>0.903926</td>
#       <td>0.096074</td>
#       <td>05:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.311100</td>
#       <td>0.171017</td>
#       <td>0.941116</td>
#       <td>0.058884</td>
#       <td>05:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.271785</td>
#       <td>0.107773</td>
#       <td>0.966942</td>
#       <td>0.033058</td>
#       <td>05:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.255081</td>
#       <td>0.090001</td>
#       <td>0.974174</td>
#       <td>0.025826</td>
#       <td>05:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# 97% before fine-tuning? That's not a bad start. How does our confusion martix look?

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46e1e4a59e1b> in <module>
# ----> 1 interp = ClassificationInterpretation.from_learner(learn)
#       2
#       3 losses,idxs = interp.top_losses()
#
# NameError: name 'ClassificationInterpretation' is not defined

# %%
interp.plot_top_losses(9, figsize=(15,11))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-34fc804e24e7> in <module>
# ----> 1 interp.plot_top_losses(9, figsize=(15,11))
#
# NameError: name 'interp' is not defined

# %% [markdown]
# So our top losses have these strange 'occlusion maps' on them. Additional pre-processing might help handle cases like this..

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Upping the ante - resnet50
#
# Okay, the last thing presented in Lecture 1 was increasing the size of the network up to a 50-layer CNN and increasing the image size. I'll try that here and let it go for 8 epochs. Keep in mind that in the Cell paper, they trained for 100 epochs to a 96.6% accuracy.
#
# First, we use the learning rate finder to find the learning rate where we're decreasing loss at the fastest rate, then use that to train the last few layers of the network (8 epochs). Then we'll unfreeze the model, train for a few more epochs to fine-tune the whole model (4 more epochs) and see how we're doing.

# %%
data = (src.transform(tfms, size=256)
        .databunch(bs=32).normalize(imagenet_stats))
learn = cnn_learner(data, models.resnet50, metrics=[accuracy, error_rate])

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 0.001
learn.fit_one_cycle(8, slice(lr))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='8', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.50% [1/8 15:47<1:50:30]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Conclusion
#
# We can get a near state-of-the-art model (maybe even better) with the fast.ai workflow, even for a seemingly complex problem like retinal pathology. There are two factors that seem to play into this
# 1. The fast.ai library works exceptionally well out of the box
# 2. Deep learning is an incredibley fast moving field
#
# This experiement is not meant to take anything away from the original authors. The task of assembling and annotating the dataset is an impressive feat in istself, and their model is incredibly good at triaging cases with a low false-positive rate. From what I can tell, ((is this in the clinic??))
#
# What this exersize does highlight is one of the barriers to entry for someone trying to get into deep learning coming from another scientific field. Things are moving so quickly, it's intimidating to catch up on the basics knowing that in 18 months a Cell paper can get surpassed by a python library. So for me, it has been really encouraging to take the library and do something useful, while still catching up on the basics as I go.
